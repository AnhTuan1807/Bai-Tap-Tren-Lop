# %% [markdown]
# <a href="https://colab.research.google.com/github/AnhTuan1807/Bai-Tap-Tren-Lop/blob/main/AI_13_09_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openpyxl import Workbook
wb = Workbook()
sheet = wb.active 
sheet ['A1'] = 'Nguyen Van A'
sheet ['B1'] = '20104003'
sheet ['A2'] = 'Le Thi B'
sheet ['B2'] = '20104254'
wb.save('/content/THONGKE.xlsx')

# %%
import openpyxl
wb = openpyxl.load_workbook('/content/THONGKE.xlsx')
sheet = wb.active 
t1 = sheet['A1']
t2 = sheet['B1']
t3 = sheet.cell(row=2,column=1)
t4 = sheet.cell(row=2,column=2)
print(t1.value, t2.value)
print(t3.value, t4.value)
# Out:
# Nguyen Van A 20104003
# Le Thi B 20104254

# %%
import openpyxl
my_wb = openpyxl.Workbook()
my_sheet = my_wb.active
c1 = my_sheet.cell(row = 1, column = 1)
c1.value = "Nguyen Van B"
c2 = my_sheet.cell(row = 1, column = 2)
c2.value = "Trinh Duc C"
c3 = my_sheet['A2']
c3.value = "Ulsan"
c4 = my_sheet['B2']
c4.value = "Genovoa"
my_wb.save('/content/THONGKE.xlsx')

# %%
import openpyxl
my_wb = openpyxl.Workbook()
my_sheet = my_wb.active
my_wb.create_sheet(index = 1, title = "KCN")
my_wb.save("/content/THONGKE.xlsx")

# %%
import openpyxl
my_path = "/content/THONGKE.xlsx"
my_wb_obj = openpyxl.load_workbook(my_path)
my_sheet_obj = my_wb_obj.active
print(my_sheet_obj.max_row)
# Out:
# 1

# %%
import openpyxl
path = "/content/THONGKE.xlsx"
My_wb_obj = openpyxl.load_workbook(path)
sheet_obj = my_wb_obj.active
print(sheet_obj.max_column)
# Out:
# 1

# %%
my_wb_obj = openpyxl.load_workbook(path)
my_sheet_obj = my_wb_obj.active
my_max_col = my_sheet_obj.max_column
for i in range(1, my_max_col +1):
  my_cell_obj = my_sheet_obj.cell(row = 1, column = i)
  print(my_cell_obj.value)
# Out:
# None

# %%
my_wb_obj = openpyxl.load_workbook(path)
my_sheet_obj = my_wb_obj.active
my_row = my_sheet_obj.max_row
for i in range(1, my_row +1):
  cell_obj = my_sheet_obj.cell(row = 1, column = i)
  print(cell_obj.value)
# Out:
# None

# %%
my_wb_obj = openpyxl.load_workbook(path)
my_sheet_obj = my_wb_obj.active
my_max_col = my_sheet_obj.max_column
for i in range(1, my_max_col +1):
  cell_obj = my_sheet_obj.cell(row = 2, column = i)
  print(cell_obj.value, end = "")
# Out:
# None

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(6)
y = x+1
plt.plot(x,y, 'o--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(6)
y = x+1
plt.plot(x,y, 'o--')
plt.plot(x,-y, 'o-')
plt.title('y=x and y=-x')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
N = 16
x = np.linspace(0,15,16)
y=x
plt.plot(x,y,'o--')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=[1,2,5,2,8,9,4,6]
plt.plot(x)
plt.show()

# %%
x=np.arange(25)
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(25)
plt.plot(x,x**3+1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(7)
plt.plot(x,-x**2)
plt.plot(x,-x**3)
plt.plot(x,-2**x)
plt.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(7)
plt.plot(x,-x**2,x,-x**3,x,-2**x,x,-2*x)
plt.grid(True)
plt.savefig('test.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(7)
plt.plot(x,-x**2,'--')
plt.plot(x,-x**3,'.')
plt.plot(x,-2**x,'_')
plt.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(7)
plt.subplots_adjust(wspace = 0.3, hspace= 0.3 )
plt.subplot(3,2,1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(7)
plt.subplots_adjust(wspace = 0.3, hspace= 0.3 )
plt.subplot(2,2,1)
plt.plot(x,x**2, color = 'red')
plt.subplot(2,2,2)
plt.plot(x,-x**3, color = 'blue')
plt.subplot(2,2,3)
plt.plot(x,-x**2, color = 'yellow')
plt.subplot(2,2,4)
plt.plot(x,-x**2, color = 'black')
plt.plot(x,-2*x)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.axis([0,150,0,100])
plt.scatter(60,50,1000, color = 'b',alpha =1)
plt.scatter(80,50,s=1000, color = 'b', alpha = .5)
plt.scatter(10,50,s=1000, color = 'b', alpha = .1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot([50,100],[100,200],linewidth = 5, color = 'b' )
plt.text(75,125,'text')
# Out:
# Text(75, 125, 'text')

# %%
plt.arrow(0.1,0.2,0.5-0.10,0.5-0.2, head_length = 4, head_width = 2, color = 'b')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x = np.arange(4)
y = np.arange(4)
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
y = np.random.rand(3,4)
plt.bar(x+0,y[0], color = 'b', width = 0.25)
plt.bar(x+0.25,y[1], color='g', width = 0.25)
plt.bar(x+0.25,y[2], color='r',width = 0.25)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x = np.arange(4)
y = np.random.rand(4)
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
N =1000
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
size = 20
plt.scatter(x,y,s=size, c=colors, alpha =1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
